# %%
import pandas as pd

# %%
df1 = pd.read_csv("data/20230906_Matrícula_unica_2023_20230430_WEB.CSV", sep = ';')
# Out:
# C:\Users\igroj\AppData\Local\Temp\ipykernel_25564\3388316834.py:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv("data/20230906_Matrícula_unica_2023_20230430_WEB.CSV", sep = ';')

# %%
df1.columns
# Out:
# Index(['AGNO', 'RBD', 'DGV_RBD', 'NOM_RBD', 'COD_REG_RBD', 'NOM_REG_RBD_A',
#        'COD_PRO_RBD', 'COD_COM_RBD', 'NOM_COM_RBD', 'COD_DEPROV_RBD',
#        'NOM_DEPROV_RBD', 'COD_DEPE', 'COD_DEPE2', 'RURAL_RBD', 'ESTADO_ESTAB',
#        'COD_ENSE', 'COD_ENSE2', 'COD_ENSE3', 'COD_GRADO', 'COD_GRADO2',
#        'LET_CUR', 'COD_JOR', 'COD_TIP_CUR', 'COD_DES_CUR', 'MRUN', 'GEN_ALU',
#        'FEC_NAC_ALU', 'EDAD_ALU', 'COD_REG_ALU', 'COD_COM_ALU', 'NOM_COM_ALU',
#        'COD_SEC', 'COD_ESPE', 'COD_RAMA', 'COD_MEN', 'ENS'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3631065 entries, 0 to 3631064
# Data columns (total 36 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   AGNO            int64
#  1   RBD             int64
#  2   DGV_RBD         int64
#  3   NOM_RBD         object
#  4   COD_REG_RBD     int64
#  5   NOM_REG_RBD_A   object
#  6   COD_PRO_RBD     int64
#  7   COD_COM_RBD     int64
#  8   NOM_COM_RBD     object
#  9   COD_DEPROV_RBD  int64
#  10  NOM_DEPROV_RBD  object
#  11  COD_DEPE        int64
#  12  COD_DEPE2       int64
#  13  RURAL_RBD       int64
#  14  ESTADO_ESTAB    int64
#  15  COD_ENSE        int64
#  16  COD_ENSE2       int64
#  17  COD_ENSE3       int64
#  18  COD_GRADO       int64
#  19  COD_GRADO2      int64
#  20  LET_CUR         object
#  21  COD_JOR         int64
#  22  COD_TIP_CUR     int64
#  23  COD_DES_CUR     int64
#  24  MRUN            int64
#  25  GEN_ALU         int64
#  26  FEC_NAC_ALU     int64
#  27  EDAD_ALU        object
# ...

# %%
df1.head(10)
# Out:
#    AGNO  RBD  DGV_RBD                  NOM_RBD  COD_REG_RBD NOM_REG_RBD_A  \
# 0  2023    1        9  LICEO POLITECNICO ARICA           15           AYP
# 1  2023    1        9  LICEO POLITECNICO ARICA           15           AYP
# 2  2023    1        9  LICEO POLITECNICO ARICA           15           AYP
# 3  2023    1        9  LICEO POLITECNICO ARICA           15           AYP
# 4  2023    1        9  LICEO POLITECNICO ARICA           15           AYP
# 5  2023    1        9  LICEO POLITECNICO ARICA           15           AYP
# 6  2023    1        9  LICEO POLITECNICO ARICA           15           AYP
# 7  2023    1        9  LICEO POLITECNICO ARICA           15           AYP
# 8  2023    1        9  LICEO POLITECNICO ARICA           15           AYP
# 9  2023    1        9  LICEO POLITECNICO ARICA           15           AYP
#
#    COD_PRO_RBD  COD_COM_RBD NOM_COM_RBD  COD_DEPROV_RBD  ... FEC_NAC_ALU  \
# 0          151        15101       ARICA             151  ...      198303
# ...

# %%
df1.isnull().sum()
# Out:
# AGNO              0
# RBD               0
# DGV_RBD           0
# NOM_RBD           0
# COD_REG_RBD       0
# NOM_REG_RBD_A     0
# COD_PRO_RBD       0
# COD_COM_RBD       0
# NOM_COM_RBD       0
# COD_DEPROV_RBD    0
# NOM_DEPROV_RBD    0
# COD_DEPE          0
# COD_DEPE2         0
# RURAL_RBD         0
# ESTADO_ESTAB      0
# COD_ENSE          0
# COD_ENSE2         0
# COD_ENSE3         0
# COD_GRADO         0
# COD_GRADO2        0
# LET_CUR           0
# COD_JOR           0
# COD_TIP_CUR       0
# COD_DES_CUR       0
# MRUN              0
# GEN_ALU           0
# FEC_NAC_ALU       0
# EDAD_ALU          0
# COD_REG_ALU       0
# COD_COM_ALU       0
# NOM_COM_ALU       0
# COD_SEC           0
# COD_ESPE          0
# COD_RAMA          0
# COD_MEN           0
# ENS               0
# dtype: int64

# %%
df1.describe()
# Out:
#             AGNO           RBD       DGV_RBD   COD_REG_RBD   COD_PRO_RBD  \
# count  3631065.0  3.631065e+06  3.631065e+06  3.631065e+06  3.631065e+06
# mean      2023.0  1.221079e+04  4.462518e+00  9.399023e+00  9.593520e+01
# std          0.0  9.336533e+03  2.877858e+00  4.013237e+00  3.992992e+01
# min       2023.0  1.000000e+00  0.000000e+00  1.000000e+00  1.100000e+01
# 25%       2023.0  4.688000e+03  2.000000e+00  6.000000e+00  6.100000e+01
# 50%       2023.0  1.005800e+04  4.000000e+00  1.000000e+01  1.010000e+02
# 75%       2023.0  1.783300e+04  7.000000e+00  1.300000e+01  1.310000e+02
# max       2023.0  4.217800e+04  9.000000e+00  1.600000e+01  1.630000e+02
#
#         COD_COM_RBD  COD_DEPROV_RBD      COD_DEPE     COD_DEPE2     RURAL_RBD  \
# count  3.631065e+06    3.631065e+06  3.631065e+06  3.631065e+06  3.631065e+06
# mean   9.600124e+03    9.452137e+01  2.853411e+00  1.955011e+00  7.745193e-02
# ...

# %%
df1.hist(bins=25, figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'AGNO'}>,
#         <Axes: title={'center': 'RBD'}>,
#         <Axes: title={'center': 'DGV_RBD'}>,
#         <Axes: title={'center': 'COD_REG_RBD'}>,
#         <Axes: title={'center': 'COD_PRO_RBD'}>],
#        [<Axes: title={'center': 'COD_COM_RBD'}>,
#         <Axes: title={'center': 'COD_DEPROV_RBD'}>,
#         <Axes: title={'center': 'COD_DEPE'}>,
#         <Axes: title={'center': 'COD_DEPE2'}>,
#         <Axes: title={'center': 'RURAL_RBD'}>],
#        [<Axes: title={'center': 'ESTADO_ESTAB'}>,
#         <Axes: title={'center': 'COD_ENSE'}>,
#         <Axes: title={'center': 'COD_ENSE2'}>,
#         <Axes: title={'center': 'COD_ENSE3'}>,
#         <Axes: title={'center': 'COD_GRADO'}>],
#        [<Axes: title={'center': 'COD_GRADO2'}>,
#         <Axes: title={'center': 'COD_JOR'}>,
#         <Axes: title={'center': 'COD_TIP_CUR'}>,
#         <Axes: title={'center': 'COD_DES_CUR'}>,
#         <Axes: title={'center': 'MRUN'}>],
# ...

# %%
df2 = pd.read_csv("data/20240628_Titulados_Ed_Superior_2023_WEB.csv", sep=";")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297174 entries, 0 to 297173
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   cat_periodo              297174 non-null  int64
#  1   codigo_unico             297174 non-null  object
#  2   mrun                     296708 non-null  float64
#  3   gen_alu                  297174 non-null  int64
#  4   fec_nac_alu              297174 non-null  int64
#  5   rango_edad               297174 non-null  object
#  6   anio_ing_carr_ori        297174 non-null  int64
#  7   sem_ing_carr_ori         297174 non-null  int64
#  8   anio_ing_carr_act        297174 non-null  int64
#  9   sem_ing_carr_act         297174 non-null  int64
#  10  nomb_titulo_obtenido     264687 non-null  object
#  11  nomb_grado_obtenido      128331 non-null  object
#  12  fecha_obtencion_titulo   297174 non-null  int64
# ...

# %%
df2.columns
# Out:
# Index(['cat_periodo', 'codigo_unico', 'mrun', 'gen_alu', 'fec_nac_alu',
#        'rango_edad', 'anio_ing_carr_ori', 'sem_ing_carr_ori',
#        'anio_ing_carr_act', 'sem_ing_carr_act', 'nomb_titulo_obtenido',
#        'nomb_grado_obtenido', 'fecha_obtencion_titulo', 'tipo_inst_1',
#        'tipo_inst_2', 'tipo_inst_3', 'cod_inst', 'nomb_inst', 'cod_sede',
#        'nomb_sede', 'cod_carrera', 'nomb_carrera', 'nivel_global',
#        'nivel_carrera_1', 'nivel_carrera_2', 'dur_estudio_carr',
#        'dur_proceso_tit', 'dur_total_carr', 'region_sede', 'provincia_sede',
#        'comuna_sede', 'jornada', 'modalidad', 'version', 'tipo_plan_carr',
#        'area_cineunesco', 'area_cine_f_97', 'subarea_cine_f_97',
#        'area_cine_f_13', 'subarea_cine_f_13', 'area_carrera_generica_n'],
#       dtype='object')

# %%
df2.head(10)
# Out:
#    cat_periodo     codigo_unico    mrun  gen_alu  fec_nac_alu     rango_edad  \
# 0         2023  I111S12C420J1V1    99.0        1       200301   20 a 24 Años
# 1         2023  I430S10C326J2V1   137.0        1       200104   20 a 24 Años
# 2         2023   I430S22C45J1V1   346.0        2       200005   20 a 24 Años
# 3         2023    I13S17C44J1V1   385.0        2       200006   20 a 24 Años
# 4         2023  I116S19C207J2V1   393.0        1       199409   25 a 29 Años
# 5         2023    I106S6C64J4V3   431.0        2       198303  40 y más años
# 6         2023     I82S1C12J1V1   442.0        2       199511   25 a 29 Años
# 7         2023    I103S8C81J1V1   637.0        2       200212   20 a 24 Años
# 8         2023    I86S5C203J1V1   808.0        2       199810   20 a 24 Años
# 9         2023     I13S12C6J1V1  1058.0        2       199907   20 a 24 Años
#
#    anio_ing_carr_ori  sem_ing_carr_ori  anio_ing_carr_act  sem_ing_carr_act  \
# ...

# %%
df2.isnull().sum()
# Out:
# cat_periodo                     0
# codigo_unico                    0
# mrun                          466
# gen_alu                         0
# fec_nac_alu                     0
# rango_edad                      0
# anio_ing_carr_ori               0
# sem_ing_carr_ori                0
# anio_ing_carr_act               0
# sem_ing_carr_act                0
# nomb_titulo_obtenido        32487
# nomb_grado_obtenido        168843
# fecha_obtencion_titulo          0
# tipo_inst_1                     0
# tipo_inst_2                     0
# tipo_inst_3                     0
# cod_inst                        0
# nomb_inst                       0
# cod_sede                        0
# nomb_sede                       0
# cod_carrera                  5752
# nomb_carrera                    0
# nivel_global                    0
# nivel_carrera_1                 0
# nivel_carrera_2                 0
# dur_estudio_carr                0
# dur_proceso_tit                 0
# ...

# %%
df2.hist(bins=25,figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'cat_periodo'}>,
#         <Axes: title={'center': 'mrun'}>,
#         <Axes: title={'center': 'gen_alu'}>,
#         <Axes: title={'center': 'fec_nac_alu'}>],
#        [<Axes: title={'center': 'anio_ing_carr_ori'}>,
#         <Axes: title={'center': 'sem_ing_carr_ori'}>,
#         <Axes: title={'center': 'anio_ing_carr_act'}>,
#         <Axes: title={'center': 'sem_ing_carr_act'}>],
#        [<Axes: title={'center': 'fecha_obtencion_titulo'}>,
#         <Axes: title={'center': 'cod_inst'}>,
#         <Axes: title={'center': 'cod_sede'}>,
#         <Axes: title={'center': 'cod_carrera'}>],
#        [<Axes: title={'center': 'dur_estudio_carr'}>,
#         <Axes: title={'center': 'dur_proceso_tit'}>,
#         <Axes: title={'center': 'dur_total_carr'}>,
#         <Axes: title={'center': 'version'}>]], dtype=object)

# %%
df3 = pd.read_csv("data/housing.csv", sep=r"\s+")

# %%
df3.head()
# Out:
#    0.00632  18.00  2.310  0  0.5380  6.5750  65.20  4.0900  1  296.0  15.30  \
# 0  0.02731    0.0   7.07  0   0.469   6.421   78.9  4.9671  2  242.0   17.8
# 1  0.02729    0.0   7.07  0   0.469   7.185   61.1  4.9671  2  242.0   17.8
# 2  0.03237    0.0   2.18  0   0.458   6.998   45.8  6.0622  3  222.0   18.7
# 3  0.06905    0.0   2.18  0   0.458   7.147   54.2  6.0622  3  222.0   18.7
# 4  0.02985    0.0   2.18  0   0.458   6.430   58.7  6.0622  3  222.0   18.7
#
#    396.90  4.98  24.00
# 0  396.90  9.14   21.6
# 1  392.83  4.03   34.7
# 2  394.63  2.94   33.4
# 3  396.90  5.33   36.2
# 4  394.12  5.21   28.7

# %%
df3.hist(bins=25, figsize=(15,15))
# Out:
# array([[<Axes: title={'center': '0.00632'}>,
#         <Axes: title={'center': '18.00'}>,
#         <Axes: title={'center': '2.310'}>, <Axes: title={'center': '0'}>],
#        [<Axes: title={'center': '0.5380'}>,
#         <Axes: title={'center': '6.5750'}>,
#         <Axes: title={'center': '65.20'}>,
#         <Axes: title={'center': '4.0900'}>],
#        [<Axes: title={'center': '1'}>, <Axes: title={'center': '296.0'}>,
#         <Axes: title={'center': '15.30'}>,
#         <Axes: title={'center': '396.90'}>],
#        [<Axes: title={'center': '4.98'}>,
#         <Axes: title={'center': '24.00'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
df4 = pd.read_csv("data/archivespotify/data.csv", sep="," )

# %%
df4.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# ...

# %%
df4.hist(bins=25, figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'valence'}>,
#         <Axes: title={'center': 'year'}>,
#         <Axes: title={'center': 'acousticness'}>,
#         <Axes: title={'center': 'danceability'}>],
#        [<Axes: title={'center': 'duration_ms'}>,
#         <Axes: title={'center': 'energy'}>,
#         <Axes: title={'center': 'explicit'}>,
#         <Axes: title={'center': 'instrumentalness'}>],
#        [<Axes: title={'center': 'key'}>,
#         <Axes: title={'center': 'liveness'}>,
#         <Axes: title={'center': 'loudness'}>,
#         <Axes: title={'center': 'mode'}>],
#        [<Axes: title={'center': 'popularity'}>,
#         <Axes: title={'center': 'speechiness'}>,
#         <Axes: title={'center': 'tempo'}>, <Axes: >]], dtype=object)
